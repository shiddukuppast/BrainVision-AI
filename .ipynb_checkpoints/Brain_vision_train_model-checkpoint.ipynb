# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras import Sequential
from keras.utils import image_dataset_from_directory
from keras.layers import Dense,BatchNormalization,Dropout,GlobalAveragePooling2D
from keras.regularizers import L2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
test_path = r"C:\Users**\user\OneDrive - REVA University\Projects\BrainVision-AI\Dataset\classification_task\test"
train_path = r"C:\Users**\user\OneDrive - REVA University\Projects\BrainVision-AI\Dataset\classification_task\train"

# %%
BATCH_SIZE = 64
EPOCH = 30
SIZE = (224,224)

# %%
train_datagen = ImageDataGenerator(rescale=1/255.0)
val_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_dataset = image_dataset_from_directory(
    train_path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=SIZE,
    batch_size=BATCH_SIZE,
)
val_dataset = image_dataset_from_directory(
    train_path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 5000 files belonging to 4 classes.
# Using 4000 files for training.
# Found 5000 files belonging to 4 classes.
# Using 1000 files for validation.

# %%
class_names = train_dataset.class_names
num_classes = len(class_names)

# %%
test_dataset = image_dataset_from_directory(
    test_path,
    image_size=SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 1000 files belonging to 4 classes.

# %%
base_model = MobileNetV2(input_shape=(224,224,3),include_top=False,weights="imagenet")
base_model.trainable = False

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.4),
    # Dense(64,activation="relu"),
    # Dropout(0.2),
    Dense(32,activation="relu"),
    Dropout(0.3),
    # Dense(16,activation="relu"),
    # Dropout(0.2),
    Dense(8,activation="relu"),
    Dense(num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy","recall"]
)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=3,
    mode="min",
    restore_best_weights=True,
    verbose=1
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCH,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.5760 - loss: 0.9787 - val_accuracy: 0.7320 - val_loss: 0.6100
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7362 - loss: 0.6609 - val_accuracy: 0.8410 - val_loss: 0.4588
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7815 - loss: 0.5414 - val_accuracy: 0.8630 - val_loss: 0.3905
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.8163 - loss: 0.4802 - val_accuracy: 0.8760 - val_loss: 0.3541
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8475 - loss: 0.4125 - val_accuracy: 0.8800 - val_loss: 0.3303
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.8512 - loss: 0.3895 - val_accuracy: 0.8830 - val_loss: 0.3226
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.8620 - loss: 0.3653 - val_accuracy: 0.8740 - val_loss: 0.3702
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8733 - loss: 0.3381 - val_accuracy: 0.8940 - val_loss: 0.2945
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8770 - loss: 0.3202 - val_accuracy: 0.8990 - val_loss: 0.2805
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.8832 - loss: 0.3127 - val_accuracy: 0.9030 - val_loss: 0.2562
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.8882 - loss: 0.2901 - val_accuracy: 0.9140 - val_loss: 0.2416
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8957 - loss: 0.2674 - val_accuracy: 0.9000 - val_loss: 0.2843
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9082 - loss: 0.2560 - val_accuracy: 0.9130 - val_loss: 0.2577
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9003 - loss: 0.2559 - val_accuracy: 0.9100 - val_loss: 0.2350
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9087 - loss: 0.2383 - val_accuracy: 0.9150 - val_loss: 0.2324
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9040 - loss: 0.2340 - val_accuracy: 0.9200 - val_loss: 0.2446
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9158 - loss: 0.2290 - val_accuracy: 0.9110 - val_loss: 0.2533
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9235 - loss: 0.2105 - val_accuracy: 0.9140 - val_loss: 0.2443
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
accuracy_score(y_true,y_pred)
# Out:
# 0.878

# %%
y_true = []
y_pred = []

for images, labels in test_dataset:
    predictions = model.predict(images, verbose=0)
    predicted_classes = np.argmax(predictions, axis=1)

    y_true.extend(labels.numpy())
    y_pred.extend(predicted_classes)

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names
))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.86      0.80      0.83       254
#   meningioma       0.81      0.80      0.80       306
#     no_tumor       0.88      0.99      0.93       140
#    pituitary       0.96      0.98      0.97       300
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.89      0.88      1000
# weighted avg       0.88      0.88      0.88      1000

# %%
cm = confusion_matrix(y_true,y_pred)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
os.makedirs("Models", exist_ok=True)
model.save("Models/brain_vision_ai.keras")
